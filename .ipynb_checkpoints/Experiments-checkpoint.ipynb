# %%
import numpy as np

from sklearn.tree import DecisionTreeRegressor
from gradboost import GradBoost
from BUTIF import BUTIF, Clustering
from rand_CART import Rand_CART
from segmentor import MSE, MeanSegmentor
from sklearn.linear_model import LogisticRegression
from RidgeCART import Ridge_CART
from HHCART import HouseHolderCART

from selector_methods import Selector

from sklearn.metrics import accuracy_score as accuracy
from pickle import load
#from sklearn.cross_validation import train_test_split, KFold

from time import clock
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datasets = load(open('datasets.pkl', 'rb'))
data_name = []
for data_key, data in datasets.items():
    data_name.append(data_key)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b5aa9f70f1f6> in <module>
# ----> 1 datasets = load(open('datasets.pkl', 'rb'))
#       2 data_name = []
#       3 for data_key, data in datasets.items():
#       4     data_name.append(data_key)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets.pkl'

# %%
data_name
# Out:
# ['ionosphere',
#  'throat surgery',
#  'wisconsin breast cancer',
#  'Indian liver',
#  'credit approval',
#  'Australian credit approval',
#  'blood transfusion',
#  'Pima Indians diabetes',
#  'mammographic mass',
#  'banknote authentication',
#  'mushroom',
#  'EEG Eye State',
#  'adult',
#  'bank marketing']

# %% [markdown]
# ## BUTIF Gradient Boosting

# %% [markdown]
# #### ionosphere

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i == 1:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  6.13636364e-01   9.00000000e+02] accuracy test:  0.715909090909
# max_leaf:  3 accuracy validation:  [  8.06818182e-01   9.48000000e+02] accuracy test:  0.829545454545
# max_leaf:  5 accuracy validation:  [  8.52272727e-01   1.34000000e+03] accuracy test:  0.886363636364
# max_leaf:  7 accuracy validation:  [  8.86363636e-01   2.31400000e+03] accuracy test:  0.886363636364
# max_leaf:  10 accuracy validation:  [  8.63636364e-01   1.19300000e+03] accuracy test:  0.875
# max_leaf:  15 accuracy validation:  [  8.75000000e-01   9.15000000e+02] accuracy test:  0.863636363636
# time:  4630.609875

# %%
np.save("BUTIF_1_cross_validation", (val_scores, best_scores, final_scores))

# %%
val_scores, best_scores, final_scores = np.load("BUTIF_1_cross_validation.npy")

# %% [markdown]
# #### throat surgery

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 1:
        i += 1
        continue
    if i == 2:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:

# %%
np.save("BUTIF_2_cross_validation", (val_scores, best_scores, final_scores))

# %%
val_scores, best_scores, final_scores = np.load("BUTIF_2_cross_validation.npy")

# %%
final_scores
# Out:
# array([ 0.83898305,  0.83898305,  0.83898305,  0.83898305,  0.83898305,
#         0.83898305])

# %% [markdown]
# #### wisconsin breast cancer

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 2:
        i += 1
        continue
    if i == 3:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

# %%
np.save("BUTIF_3_cross_validation", (val_scores, best_scores, final_scores))

# %%
val_scores, best_scores, final_scores = np.load("BUTIF_3_cross_validation.npy")

# %%
final_scores
# Out:
# array([ 0.90909091,  0.88811189,  0.95104895,  0.95804196,  0.95104895,
#         0.93706294])

# %% [markdown]
# #### Indian liver

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 3:
        i += 1
        continue
    if i == 4:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

# %%
np.save("BUTIF_4_cross_validation", (val_scores, best_scores, final_scores))

# %%
val_scores, best_scores, final_scores = np.load("BUTIF_4_cross_validation.npy")

# %%
final_scores
# Out:
# array([ 0.70344828,  0.70344828,  0.67586207,  0.67586207,  0.68965517,
#         0.68965517])

# %% [markdown]
# #### credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 4:
        i += 1
        continue
    if i == 5:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  6.80981595e-01   1.02600000e+03] accuracy test:  0.689024390244
# max_leaf:  3 accuracy validation:  [  7.91411043e-01   1.08900000e+03] accuracy test:  0.786585365854
# max_leaf:  5 accuracy validation:  [  8.28220859e-01   9.85000000e+02] accuracy test:  0.835365853659
# max_leaf:  7 accuracy validation:  [  8.28220859e-01   1.82700000e+03] accuracy test:  0.859756097561
# max_leaf:  10 accuracy validation:  [  8.15950920e-01   9.44000000e+02] accuracy test:  0.829268292683
# max_leaf:  15 accuracy validation:  [  8.28220859e-01   1.26200000e+03] accuracy test:  0.853658536585
# time:  6568.790996

# %%
np.save("BUTIF_5_cross_validation", (val_scores, best_scores, final_scores))

# %%
val_scores, best_scores, final_scores = np.load("BUTIF_5_cross_validation.npy")

# %%
final_scores
# Out:
# array([ 0.70344828,  0.70344828,  0.68965517,  0.66896552,  0.66206897,
#         0.65517241])

# %% [markdown]
# #### Australian credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 5:
        i += 1
        continue
    if i == 6:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

# %%
np.save("BUTIF_6_cross_validation", (val_scores, best_scores, final_scores))

# %%
val_scores, best_scores, final_scores = np.load("BUTIF_6_cross_validation.npy")

# %%
final_scores
# Out:
# array([ 0.82080925,  0.86127168,  0.83815029,  0.84393064,  0.85549133,
#         0.84971098])

# %% [markdown]
# #### blood transfusion

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 6:
        i += 1
        continue
    if i == 7:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  8.02139037e-01   9.01000000e+02] accuracy test:  0.75935828877
# max_leaf:  3 accuracy validation:  [  8.23529412e-01   1.38200000e+03] accuracy test:  0.754010695187
# max_leaf:  5 accuracy validation:  [  8.07486631e-01   1.68100000e+03] accuracy test:  0.770053475936
# max_leaf:  7 accuracy validation:  [  8.18181818e-01   2.03100000e+03] accuracy test:  0.775401069519
# max_leaf:  10 accuracy validation:  [  8.02139037e-01   9.03000000e+02] accuracy test:  0.786096256684
# max_leaf:  15 accuracy validation:  [  7.91443850e-01   9.12000000e+02] accuracy test:  0.770053475936
# time:  4109.796258

# %%
np.save("BUTIF_7_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### Pima Indians diabetes

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 7:
        i += 1
        continue
    if i == 8:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  6.71875000e-01   1.63900000e+03] accuracy test:  0.6875
# max_leaf:  3 accuracy validation:  [  6.82291667e-01   9.03000000e+02] accuracy test:  0.609375
# max_leaf:  5 accuracy validation:  [  7.03125000e-01   1.24800000e+03] accuracy test:  0.703125
# max_leaf:  7 accuracy validation:  [  6.97916667e-01   1.09200000e+03] accuracy test:  0.744791666667
# max_leaf:  10 accuracy validation:  [  7.03125000e-01   9.09000000e+02] accuracy test:  0.755208333333
# max_leaf:  15 accuracy validation:  [  7.13541667e-01   9.56000000e+02] accuracy test:  0.770833333333
# time:  4438.399455000001

# %%
np.save("BUTIF_8_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### mammographic mass

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 8:
        i += 1
        continue
    if i == 9:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  7.78846154e-01   9.10000000e+02] accuracy test:  0.75
# max_leaf:  3 accuracy validation:  [  7.74038462e-01   9.01000000e+02] accuracy test:  0.769230769231
# max_leaf:  5 accuracy validation:  [  7.88461538e-01   9.02000000e+02] accuracy test:  0.788461538462
# max_leaf:  7 accuracy validation:  [  8.02884615e-01   1.10200000e+03] accuracy test:  0.802884615385
# max_leaf:  10 accuracy validation:  [  7.93269231e-01   1.09300000e+03] accuracy test:  0.788461538462
# max_leaf:  15 accuracy validation:  [  7.93269231e-01   9.63000000e+02] accuracy test:  0.783653846154
# time:  6755.393080000002

# %%
np.save("BUTIF_9_cross_validation", (val_scores, best_scores, final_scores))

# %%
val_scores, best_scores, final_scores = np.load("BUTIF_9_cross_validation.npy")

# %%
plt.plot(np.arange(100), val_scores[:100, :])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa4845d1c88>,
#  <matplotlib.lines.Line2D at 0x7fa4845d1e10>,
#  <matplotlib.lines.Line2D at 0x7fa4845d80f0>,
#  <matplotlib.lines.Line2D at 0x7fa4845d82e8>,
#  <matplotlib.lines.Line2D at 0x7fa4845d84e0>,
#  <matplotlib.lines.Line2D at 0x7fa4845d86d8>]

# %% [markdown]
# #### banknote authentication

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 9:
        i += 1
        continue
    if i == 10:
        break
    X_train = data.X_train
    _, n_features = X_train.shape
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(BUTIF(max_leaf=max_leaf, 
                            linear_model=LogisticRegression(n_jobs=-1, penalty='l1'), 
                            task='regression'), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  5.24781341e-01   9.01000000e+02] accuracy test:  0.545189504373
# max_leaf:  3 accuracy validation:  [  7.02623907e-01   1.78700000e+03] accuracy test:  0.696793002915
# max_leaf:  5 accuracy validation:  [  9.24198251e-01   1.62300000e+03] accuracy test:  0.900874635569
# max_leaf:  7 accuracy validation:  [  9.62099125e-01   3.00000000e+03] accuracy test:  0.950437317784
# max_leaf:  10 accuracy validation:  [  1.00000000e+00   1.16800000e+03] accuracy test:  1.0
# max_leaf:  15 accuracy validation:  [   1.  933.] accuracy test:  1.0
# time:  5541.270236

# %%
np.save("BUTIF_10_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# #### ionosphere

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i == 1:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [   0.90909091  909.        ] accuracy test:  0.909090909091
# max_leaf:  3 accuracy validation:  [   0.92045455  901.        ] accuracy test:  0.863636363636
# max_leaf:  5 accuracy validation:  [   0.93181818  901.        ] accuracy test:  0.863636363636
# max_leaf:  7 accuracy validation:  [  8.06818182e-01   9.01000000e+02] accuracy test:  0.795454545455
# max_leaf:  10 accuracy validation:  [   0.92045455  902.        ] accuracy test:  0.863636363636
# max_leaf:  15 accuracy validation:  [  8.97727273e-01   9.01000000e+02] accuracy test:  0.852272727273
# time:  42.18028100000083

# %%
np.save("gradboost_1_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### throat surgery

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 1:
        i += 1
        continue
    if i == 2:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  7.43589744e-01   9.02000000e+02] accuracy test:  0.822033898305
# max_leaf:  3 accuracy validation:  [  7.94871795e-01   9.03000000e+02] accuracy test:  0.805084745763
# max_leaf:  5 accuracy validation:  [  7.60683761e-01   9.03000000e+02] accuracy test:  0.779661016949
# max_leaf:  7 accuracy validation:  [  7.86324786e-01   9.02000000e+02] accuracy test:  0.771186440678
# max_leaf:  10 accuracy validation:  [  7.60683761e-01   9.03000000e+02] accuracy test:  0.779661016949
# max_leaf:  15 accuracy validation:  [  7.69230769e-01   9.02000000e+02] accuracy test:  0.771186440678
# time:  53.50300799999968

# %%
np.save("gradboost_2_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### wisconsin breast cancer

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 2:
        i += 1
        continue
    if i == 3:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [   0.94366197  916.        ] accuracy test:  0.909090909091
# max_leaf:  3 accuracy validation:  [   0.92253521  902.        ] accuracy test:  0.909090909091
# max_leaf:  5 accuracy validation:  [   0.91549296  901.        ] accuracy test:  0.916083916084
# max_leaf:  7 accuracy validation:  [   0.91549296  902.        ] accuracy test:  0.895104895105
# max_leaf:  10 accuracy validation:  [   0.92253521  902.        ] accuracy test:  0.916083916084
# max_leaf:  15 accuracy validation:  [   0.91549296  901.        ] accuracy test:  0.916083916084
# time:  42.19308100000126

# %%
np.save("gradboost_3_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### Indian liver

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 3:
        i += 1
        continue
    if i == 4:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  7.17241379e-01   9.96000000e+02] accuracy test:  0.668965517241
# max_leaf:  3 accuracy validation:  [  6.96551724e-01   1.05200000e+03] accuracy test:  0.620689655172
# max_leaf:  5 accuracy validation:  [  6.82758621e-01   9.22000000e+02] accuracy test:  0.606896551724
# max_leaf:  7 accuracy validation:  [  6.41379310e-01   9.03000000e+02] accuracy test:  0.620689655172
# max_leaf:  10 accuracy validation:  [  6.68965517e-01   9.06000000e+02] accuracy test:  0.655172413793
# max_leaf:  15 accuracy validation:  [  6.48275862e-01   9.02000000e+02] accuracy test:  0.668965517241
# time:  51.44507599999997

# %%
np.save("gradboost_4_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 4:
        i += 1
        continue
    if i == 5:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  8.09815951e-01   9.01000000e+02] accuracy test:  0.829268292683
# max_leaf:  3 accuracy validation:  [  7.73006135e-01   9.01000000e+02] accuracy test:  0.80487804878
# max_leaf:  5 accuracy validation:  [  7.54601227e-01   9.04000000e+02] accuracy test:  0.774390243902
# max_leaf:  7 accuracy validation:  [  7.91411043e-01   9.09000000e+02] accuracy test:  0.817073170732
# max_leaf:  10 accuracy validation:  [  8.34355828e-01   9.04000000e+02] accuracy test:  0.810975609756
# max_leaf:  15 accuracy validation:  [  8.03680982e-01   9.01000000e+02] accuracy test:  0.774390243902
# time:  51.34132200000022

# %%
np.save("gradboost_5_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### Australian credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 5:
        i += 1
        continue
    if i == 6:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  8.08139535e-01   1.07400000e+03] accuracy test:  0.820809248555
# max_leaf:  3 accuracy validation:  [  7.38372093e-01   9.01000000e+02] accuracy test:  0.815028901734
# max_leaf:  5 accuracy validation:  [  7.79069767e-01   9.02000000e+02] accuracy test:  0.780346820809
# max_leaf:  7 accuracy validation:  [  7.96511628e-01   9.06000000e+02] accuracy test:  0.815028901734
# max_leaf:  10 accuracy validation:  [  8.02325581e-01   9.01000000e+02] accuracy test:  0.780346820809
# max_leaf:  15 accuracy validation:  [  7.84883721e-01   9.01000000e+02] accuracy test:  0.791907514451
# time:  52.42132000000129

# %%
np.save("gradboost_6_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### blood transfusion

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 6:
        i += 1
        continue
    if i == 7:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  7.86096257e-01   9.59000000e+02] accuracy test:  0.764705882353
# max_leaf:  3 accuracy validation:  [  7.96791444e-01   9.19000000e+02] accuracy test:  0.737967914439
# max_leaf:  5 accuracy validation:  [  7.64705882e-01   9.47000000e+02] accuracy test:  0.748663101604
# max_leaf:  7 accuracy validation:  [  7.64705882e-01   9.01000000e+02] accuracy test:  0.679144385027
# max_leaf:  10 accuracy validation:  [  7.91443850e-01   1.14600000e+03] accuracy test:  0.700534759358
# max_leaf:  15 accuracy validation:  [  7.70053476e-01   9.08000000e+02] accuracy test:  0.716577540107
# time:  83.14041300000099

# %%
np.save("gradboost_7_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### Pima Indians diabetes

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 7:
        i += 1
        continue
    if i == 8:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  6.97916667e-01   9.22000000e+02] accuracy test:  0.791666666667
# max_leaf:  3 accuracy validation:  [  6.87500000e-01   9.08000000e+02] accuracy test:  0.723958333333
# max_leaf:  5 accuracy validation:  [  6.40625000e-01   9.04000000e+02] accuracy test:  0.71875
# max_leaf:  7 accuracy validation:  [  6.51041667e-01   9.01000000e+02] accuracy test:  0.755208333333
# max_leaf:  10 accuracy validation:  [  6.92708333e-01   9.01000000e+02] accuracy test:  0.734375
# max_leaf:  15 accuracy validation:  [  6.82291667e-01   9.03000000e+02] accuracy test:  0.697916666667
# time:  58.04239200000302

# %%
np.save("gradboost_8_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### mammographic mass

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 8:
        i += 1
        continue
    if i == 9:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [  7.93269231e-01   1.29700000e+03] accuracy test:  0.788461538462
# max_leaf:  3 accuracy validation:  [  7.78846154e-01   9.21000000e+02] accuracy test:  0.764423076923
# max_leaf:  5 accuracy validation:  [  7.59615385e-01   1.00000000e+03] accuracy test:  0.759615384615
# max_leaf:  7 accuracy validation:  [  7.25961538e-01   9.03000000e+02] accuracy test:  0.730769230769
# max_leaf:  10 accuracy validation:  [  7.64423077e-01   9.01000000e+02] accuracy test:  0.764423076923
# max_leaf:  15 accuracy validation:  [  7.59615385e-01   9.06000000e+02] accuracy test:  0.730769230769
# time:  88.59977399999843

# %%
np.save("gradboost_9_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### banknote authentication

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 9:
        i += 1
        continue
    if i == 10:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_leaves = [2, 3, 5, 7, 10, 15]
    
    best_scores = np.zeros((len(max_leaves), 2))
    val_scores = np.zeros((n_estimators, len(max_leaves)))
    final_scores = np.zeros(len(max_leaves))
    for k, max_leaf in enumerate(max_leaves):
        clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=max_leaf), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_leaf: ", max_leaf,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_leaf:  2 accuracy validation:  [   0.9941691  977.       ] accuracy test:  0.991253644315
# max_leaf:  3 accuracy validation:  [   0.98250729  934.        ] accuracy test:  0.985422740525
# max_leaf:  5 accuracy validation:  [   0.98542274  912.        ] accuracy test:  0.98250728863
# max_leaf:  7 accuracy validation:  [   0.97959184  905.        ] accuracy test:  0.965014577259
# max_leaf:  10 accuracy validation:  [   0.98833819  903.        ] accuracy test:  0.98250728863
# max_leaf:  15 accuracy validation:  [   0.98250729  901.        ] accuracy test:  0.97084548105
# time:  53.85769900000014

# %%
np.save("gradboost_10_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# |*Датасеты*|**BUTIF Gradient Boosting**|**Gradient Boosting**|
# |------------------------------------------------------------|
# |ionosphere|0.886|**0.898**|
# |throat surgery|**0.839**|**0.839**|
# |wisconsin breast cancer|**0.951**|0.937|
# |Indian liver|**0.703**|**0.703**|
# |credit approval|**0.86**|0.841|
# |Australian credit approval|0.85|**0.861**|
# |blood transfusion|**0.78**|0.765|
# |Pima Indians diabetes|0.708|**0.76**|
# |mammographic mass|0.784|**0.808**|
# |banknote authentication|**1.0**|0.985|

# %% [markdown]
# ## Random CART Boosting

# %% [markdown]
# #### ionosphere

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i == 1:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [  8.52272727e-01   9.62000000e+02] accuracy test:  0.863636363636
# max_depth:  2 accuracy validation:  [  8.97727273e-01   1.06700000e+03] accuracy test:  0.886363636364
# max_depth:  3 accuracy validation:  [  9.09090909e-01   9.85000000e+02] accuracy test:  0.909090909091
# max_depth:  5 accuracy validation:  [  9.20454545e-01   1.07800000e+03] accuracy test:  0.897727272727
# max_depth:  7 accuracy validation:  [  8.52272727e-01   9.20000000e+02] accuracy test:  0.886363636364
# time:  2911.8725710000003

# %%
np.save("randcart_1_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### throat surgery

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 1:
        i += 1
        continue
    if i == 2:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [  8.20512821e-01   9.01000000e+02] accuracy test:  0.822033898305
# max_depth:  2 accuracy validation:  [  8.29059829e-01   9.01000000e+02] accuracy test:  0.822033898305
# max_depth:  3 accuracy validation:  [  8.54700855e-01   1.31600000e+03] accuracy test:  0.822033898305
# max_depth:  5 accuracy validation:  [  8.29059829e-01   9.88000000e+02] accuracy test:  0.822033898305
# max_depth:  7 accuracy validation:  [  8.54700855e-01   9.32000000e+02] accuracy test:  0.822033898305
# time:  3537.5603610000003

# %%
np.save("randcart_2_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### wisconsin breast cancer

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 2:
        i += 1
        continue
    if i == 3:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [
cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### mammographic mass

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 8:
        i += 1
        continue
    if i == 9:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [  8.02884615e-01   1.06200000e+03] accuracy test:  0.8125
# max_depth:  2 accuracy validation:  [  7.88461538e-01   9.05000000e+02] accuracy test:  0.802884615385
# max_depth:  3 accuracy validation:  [  7.83653846e-01   9.33000000e+02] accuracy test:  0.793269230769
# max_depth:  5 accuracy validation:  [  7.54807692e-01   9.02000000e+02] accuracy test:  0.764423076923
# max_depth:  7 accuracy validation:  [  7.35576923e-01   9.06000000e+02] accuracy test:  0.764423076923
# time:  1763.9688119999992

# %%
np.save("randcart_9_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### banknote authentication

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 9:
        i += 1
        continue
    if i == 10:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [  1.00000000e+00   1.54100000e+03] accuracy test:  1.0
# max_depth:  2 accuracy validation:  [  1.00000000e+00   1.00100000e+03] accuracy test:  1.0
# max_depth:  3 accuracy validation:  [   1.  934.] accuracy test:  1.0
# max_depth:  5 accuracy validation:  [   0.99708455  903.        ] accuracy test:  1.0
# max_depth:  7 accuracy validation:  [   1.  902.] accuracy test:  1.0
# time:  772.1849030000012

# %%
np.save("randcart_10_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# ## Random CART with back

# %% [markdown]
# #### ionosphere

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i == 1:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth, compare_with_cart=True), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [  8.06818182e-01   9.75000000e+02] accuracy test:  0.875
# max_depth:  2 accuracy validation:  [  8.18181818e-01   9.12000000e+02] accuracy test:  0.863636363636
# max_depth:  3 accuracy validation:  [   0.93181818  913.        ] accuracy test:  0.875
# max_depth:  5 accuracy validation:  [  9.20454545e-01   9.58000000e+02] accuracy test:  0.909090909091
# max_depth:  7 accuracy validation:  [  8.63636364e-01   9.01000000e+02] accuracy test:  0.886363636364
# time:  3234.415288

# %%
np.save("randcart_back_1_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### throat surgery

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 1:
        i += 1
        continue
    if i == 2:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth, compare_with_cart=True), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [  8.29059829e-01   9.01000000e+02] accuracy test:  0.813559322034
# max_depth:  2 accuracy validation:  [  8.54700855e-01   9.25000000e+02] accuracy test:  0.813559322034
# max_depth:  3 accuracy validation:  [  8.29059829e-01   9.02000000e+02] accuracy test:  0.830508474576
# max_depth:  5 accuracy validation:  [  8.46153846e-01   9.48000000e+02] accuracy test:  0.830508474576
# max_depth:  7 accuracy validation:  [  8.37606838e-01   9.17000000e+02] accuracy test:  0.822033898305
# time:  4678.489270000002

# %%
np.save("randcart_back_2_cross_validation", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### wisconsin breast cancer

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 2:
        i += 1
        continue
    if i == 3:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth, compare_with_cart=True), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("randcart_back_3_cross_validation", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [   0.98591549  945.        ] accuracy test:  0.965034965035
# max_depth:  2 accuracy validation:  [  9.78873239e-01   1.34800000e+03] accuracy test:  0.958041958042
# max_depth:  3 accuracy validation:  [   0.97887324  909.        ] accuracy test:  0.951048951049
# max_depth:  5 accuracy validation:  [   0.97183099  925.        ] accuracy test:  0.965034965035
# max_depth:  7 accuracy validation:  [   0.94366197  923.        ] accuracy test:  0.93006993007
# time:  4173.046899999998

# %% [markdown]
# #### Indian liver

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 3:
        i += 1
        continue
    if i == 4:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth, compare_with_cart=True), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("randcart_back_4_cross_validation", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [  6.48275862e-01   9.01000000e+02] accuracy test:  0.689655172414
# max_depth:  2 accuracy validation:  [  6.75862069e-01   9.95000000e+02] accuracy test:  0.68275862069
# max_depth:  3 accuracy validation:  [  7.03448276e-01   1.09600000e+03] accuracy test:  0.731034482759
# max_depth:  5 accuracy validation:  [  6.75862069e-01   1.09200000e+03] accuracy test:  0.737931034483
# max_depth:  7 accuracy validation:  [  7.03448276e-01   9.20000000e+02] accuracy test:  0.71724137931
# time:  1854.4731709999978

# %% [markdown]
# #### credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 4:
        i += 1
        continue
    if i == 5:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=max_depth, compare_with_cart=True), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("randcart_back
# %% [markdown]
# #### wisconsin breast cancer

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 2:
        i += 1
        continue
    if i == 3:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_3_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy validation:  [   0.95070423  901.        ] accuracy test:  0.972027972028
# max_depth:  2 accuracy validation:  [   0.95070423  905.        ] accuracy test:  0.951048951049
# max_depth:  3 accuracy validation:  [   0.95070423  908.        ] accuracy test:  0.979020979021
# max_depth:  5 accuracy validation:  [   0.95070423  920.        ] accuracy test:  0.958041958042
# max_depth:  7 accuracy validation:  [   0.95070423  906.        ] accuracy test:  0.937062937063
# time:  4353.33397

# %%
plt.plot(np.arange(100), clf.loss_val[:100])

# %% [markdown]
# #### Indian liver

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 3:
        i += 1
        continue
    if i == 4:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_4_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 4:
        i += 1
        continue
    if i == 5:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_5_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### Australian credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 5:
        i += 1
        continue
    if i == 6:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_6_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### blood transfusion

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 6:
        i += 1
        continue
    if i == 7:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_7_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### Pima Indians diabetes

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 7:
        i += 1
        continue
    if i == 8:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_8_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### mammographic mass

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 8:
        i += 1
        continue
    if i == 9:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_9_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))

# %% [markdown]
# #### banknote authentication

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 9:
        i += 1
        continue
    if i == 10:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [1, 2, 3, 5, 7]
    
    best_scores = np.zeros((len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(max_depths)))
    final_scores = np.zeros(len(max_depths))
    for k, max_depth in enumerate(max_depths):
        clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=max_depth, method='ridge', alpha=1.0), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
        val_scores[:, k] = 1 - np.asarray(clf.loss_val)
        best_scores[k, 0] = val_scores[clf.base_learners_count - 1, k]
        best_scores[k, 1] = clf.base_learners_count
        y_pred = clf.predict(X_test)
        final_scores[k] = accuracy(y_pred, y_test)
        print("max_depth: ", max_depth,
              "accuracy validation: ", best_scores[k],
              "accuracy test: ", final_scores[k])
    i += 1
    
    print("time: ", clock() - start)

np.save("hhcartreg_10_cross_val_alpha=1.0", (val_scores, best_scores, final_scores))

# %% [markdown]
# ## RidgeCART

# %% [markdown]
# #### ionosphere

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i == 1:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("Ridge_CART_1", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  8.06818182e-01   9.31000000e+02] accuracy test:  0.852272727273
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  7.72727273e-01   9.01000000e+02] accuracy test:  0.795454545455
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.72727273e-01   9.01000000e+02] accuracy test:  0.795454545455
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  7.72727273e-01   9.01000000e+02] accuracy test:  0.795454545455
# alpha:  0.001 max_depth:  2 accuracy validation:  [  8.06818182e-01   9.31000000e+02] accuracy test:  0.852272727273
# alpha:  0.001 max_depth:  3 accuracy validation:  [  7.61363636e-01   9.01000000e+02] accuracy test:  0.818181818182
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.61363636e-01   9.01000000e+02] accuracy test:  0.818181818182
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.61363636e-01   9.01000000e+02] accuracy test:  0.818181818182
# alpha:  1.0 max_depth:  2 accuracy validation:  [  8.29545455e-01   9.31000000e+02] accuracy test:  0.840909090909
# alpha:  1.0 max_depth:  3 accuracy validation:  [  8.86363636e-01   9.01000000e+02] accuracy test:  0.829545454545
# alpha:  1.0 max_depth:  5 accuracy validation:  [  8.52272727e-01   9.35000000e+02] accuracy test:  0.829545454545
# alpha:  1.0 max_depth:  7 accuracy validation:  [  8.18181818e-01   9.01000000e+02] accuracy test:  0.806818181818
# alpha:  10.0 max_depth:  2 accuracy validation:  [  8.52272727e-01   9.32000000e+02] accuracy test:  0.806818181818
# alpha:  10.0 max_depth:  3 accuracy validation:  [  8.75000000e-01   9.13000000e+02] accuracy test:  0.772727272727
# alpha:  10.0 max_depth:  5 accuracy validation:  [  8.40909091e-01   9.12000000e+02] accuracy test:  0.863636363636
# alpha:  10.0 max_depth:  7 accuracy validation:  [  7.72727273e-01   9.04000000e+02] accuracy test:  0.818181818182
# alpha:  100.0 max_depth:  2 accuracy validation:  [  8.40909091e-01   9.39000000e+02] accuracy test:  0.852272727273
# alpha:  100.0 max_depth:  3 accuracy validation:  [  8.86363636e-01   9.33000000e+02] accuracy test:  0.863636363636
# alpha:  100.0 max_depth:  5 accuracy validation:  [  7.95454545e-01   9.09000000e+02] accuracy test:  0.852272727273
# alpha:  100.0 max_depth:  7 accuracy validation:  [  8.86363636e-01   9.11000000e+02] accuracy test:  0.897727272727
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  8
# alpha:  1.0 max_depth:  2 accuracy validation:  [   0.94366197  902.        ] accuracy test:  0.951048951049
# alpha:  1.0 max_depth:  3 accuracy validation:  [   0.95070423  902.        ] accuracy test:  0.958041958042
# alpha:  1.0 max_depth:  5 accuracy validation:  [   0.92253521  902.        ] accuracy test:  0.944055944056
# alpha:  1.0 max_depth:  7 accuracy validation:  [   0.94366197  901.        ] accuracy test:  0.937062937063
# alpha:  10.0 max_depth:  2 accuracy validation:  [   0.95774648  920.        ] accuracy test:  0.965034965035
# alpha:  10.0 max_depth:  3 accuracy validation:  [   0.96478873  903.        ] accuracy test:  0.951048951049
# alpha:  10.0 max_depth:  5 accuracy validation:  [   0.95070423  902.        ] accuracy test:  0.93006993007
# alpha:  10.0 max_depth:  7 accuracy validation:  [   0.93661972  901.        ] accuracy test:  0.944055944056
# alpha:  100.0 max_depth:  2 accuracy validation:  [   0.99295775  920.        ] accuracy test:  0.958041958042
# alpha:  100.0 max_depth:  3 accuracy validation:  [   0.96478873  915.        ] accuracy test:  0.937062937063
# alpha:  100.0 max_depth:  5 accuracy validation:  [   0.95070423  909.        ] accuracy test:  0.944055944056
# alpha:  100.0 max_depth:  7 accuracy validation:  [   0.92253521  904.        ] accuracy test:  0.93006993007
# alpha:  1000.0 max_depth:  2 accuracy validation:  [   0.97183099  928.        ] accuracy test:  0.944055944056
# alpha:  1000.0 max_depth:  3 accuracy validation:  [   0.97887324  929.        ] accuracy test:  0.944055944056
# alpha:  1000.0 max_depth:  5 accuracy validation:  [   0.95774648  902.        ] accuracy test:  0.951048951049
# alpha:  1000.0 max_depth:  7 accuracy validation:  [   0.95070423  901.        ] accuracy test:  0.916083916084
# time:  5648.225363000005

# %% [markdown]
# #### Indian liver

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 3:
        i += 1
        continue
    if i == 4:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("Ridge_CART_4", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  6.82758621e-01   9.09000000e+02] accuracy test:  0.668965517241
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  6.75862069e-01   9.01000000e+02] accuracy test:  0.668965517241
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  6.27586207e-01   9.02000000e+02] accuracy test:  0.662068965517
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  6.96551724e-01   9.77000000e+02] accuracy test:  0.634482758621
# alpha:  0.001 max_depth:  2 accuracy validation:  [  6.82758621e-01   9.09000000e+02] accuracy test:  0.668965517241
# alpha:  0.001 max_depth:  3 accuracy validation:  [  6.68965517e-01   9.01000000e+02] accuracy test:  0.696551724138
# alpha:  0.001 max_depth:  5 accuracy validation:  [  6.55172414e-01   9.04000000e+02] accuracy test:  0.627586206897
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.24137931e-01   9.33000000e+02] accuracy test:  0.662068965517
# alpha:  1.0 max_depth:  2 accuracy validation:  [  6.75862069e-01   9.10000000e+02] accuracy test:  0.675862068966
# alpha:  1.0 max_depth:  3 accuracy validation:  [  6.62068966e-01   9.01000000e+02] accuracy test:  0.696551724138
# alpha:  1.0 max_depth:  5 accuracy validation:  [  6.41379310e-01   9.03000000e+02] accuracy test:  0.648275862069
# alpha:  1.0 max_depth:  7 accuracy validation:  [  6.48275862e-01   9.04000000e+02] accuracy test:  0.703448275862
# alpha:  10.0 max_depth:  2 accuracy validation:  [  6.96551724e-01   9.17000000e+02] accuracy test:  0.655172413793
# alpha:  10.0 max_depth:  3 accuracy validation:  [  7.03448276e-01   9.57000000e+02] accuracy test:  0.689655172414
# alpha:  10.0 max_depth:  5 accuracy validation:  [  6.62068966e-01   9.21000000e+02] accuracy test:  0.606896551724
# alpha:  10.0 max_depth:  7 accuracy validation:  [  7
# alpha:  1.0 max_depth:  3 accuracy validation:  [  1.00000000e+00   1.11700000e+03] accuracy test:  0.991253644315
# alpha:  1.0 max_depth:  5 accuracy validation:  [   0.99708455  903.        ] accuracy test:  0.991253644315
# alpha:  1.0 max_depth:  7 accuracy validation:  [   0.99708455  901.        ] accuracy test:  0.997084548105
# alpha:  10.0 max_depth:  2 accuracy validation:  [   0.98833819  916.        ] accuracy test:  0.985422740525
# alpha:  10.0 max_depth:  3 accuracy validation:  [   0.99708455  975.        ] accuracy test:  0.991253644315
# alpha:  10.0 max_depth:  5 accuracy validation:  [   0.99708455  905.        ] accuracy test:  0.997084548105
# alpha:  10.0 max_depth:  7 accuracy validation:  [   0.9941691  901.       ] accuracy test:  1.0
# alpha:  100.0 max_depth:  2 accuracy validation:  [   0.9941691  918.       ] accuracy test:  0.991253644315
# alpha:  100.0 max_depth:  3 accuracy validation:  [   1.  915.] accuracy test:  1.0
# alpha:  100.0 max_depth:  5 accuracy validation:  [   0.9941691  907.       ] accuracy test:  0.99416909621
# alpha:  100.0 max_depth:  7 accuracy validation:  [   0.9941691  908.       ] accuracy test:  0.99416909621
# alpha:  1000.0 max_depth:  2 accuracy validation:  [   0.99708455  959.        ] accuracy test:  0.997084548105
# alpha:  1000.0 max_depth:  3 accuracy validation:  [   1.  946.] accuracy test:  0.997084548105
# alpha:  1000.0 max_depth:  5 accuracy validation:  [   0.99708455  901.        ] accuracy test:  1.0
# alpha:  1000.0 max_depth:  7 accuracy validation:  [   0.99708455  901.        ] accuracy test:  1.0
# time:  2845.3903740000096

# %% [markdown]
# ## Hard Ridge CART

# %% [markdown]
# Используется только один признак $x^T\beta$, где $\beta$ обучено по Ridge-регрессии.

# %% [markdown]
# #### ionosphere

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i == 1:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_1", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  8.29545455e-01   9.18000000e+02] accuracy test:  0.852272727273
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  7.84090909e-01   9.01000000e+02] accuracy test:  0.795454545455
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.84090909e-01   9.01000000e+02] accuracy test:  0.795454545455
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  7.84090909e-01   9.01000000e+02] accuracy test:  0.795454545455
# alpha:  0.001 max_depth:  2 accuracy validation:  [  8.29545455e-01   9.18000000e+02] accuracy test:  0.840909090909
# alpha:  0.001 max_depth:  3 accuracy validation:  [  7.72727273e-01   9.01000000e+02] accuracy test:  0.818181818182
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.72727273e-01   9.01000000e+02] accuracy test:  0.818181818182
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.72727273e-01   9.01000000e+02] accuracy test:  0.818181818182
# alpha:  1.0 max_depth:  2 accuracy validation:  [  8.29545455e-01   9.34000000e+02] accuracy test:  0.852272727273
# alpha:  1.0 max_depth:  3 accuracy validation:  [  8.75000000e-01   9.01000000e+02] accuracy test:  0.784090909091
# alpha:  1.0 max_depth:  5 accuracy validation:  [  8.29545455e-01   9.01000000e+02] accuracy test:  0.784090909091
# alpha:  1.0 max_depth:  7 accuracy validation:  [  8.63636364e-01   9.01000000e+02] accuracy test:  0.784090909091
# alpha:  10.0 max_depth:  2 accuracy validation:  [  8.63636364e-01   1.26300000e+03] accuracy test:  0.886363636364
# alpha:  10.0 max_depth:  3 accuracy validation:  [  7.95454545e-01   9.10000000e+02] accuracy test:  0.75
# alpha:  10.0 max_depth:  5 accuracy validation:  [  8.29545455e-01   9.06000000e+02] accuracy test:  0.829545454545
# alpha:  10.0 max_depth:  7 accuracy validation:  [  8.63636364e-01   9.29000000e+02] accuracy test:  0.806818181818
# alpha:  100.0 max_depth:  2 accuracy validation:  [  8.63636364e-01   1.00700000e+03] accuracy test:  0.840909090909
# alpha:  100.0 max_depth:  3 accuracy validation:  [  8.63636364e-01   9.96000000e+02] accuracy test:  0.875
# alpha:  100.0 max_depth:  5 accuracy validation:  [  9.09090909e-01   1.11000000e+03] accuracy test:  0.852272727273
# alpha:  100.0 max_depth:  7 accuracy validation:  [  8.86363636e-01   9.01000000e+02] accuracy test:  0.863636363636
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  8.75000000e-01   1.05500000e+03] accuracy test:  0.863636363636
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  8.75000000e-01   1.04900000e+03] accuracy test:  0.875
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  8.40909091e-01   9.16000000e+02] accuracy test:  0.875
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  8.52272727e-01   9.14000000e+02] accuracy test:  0.875
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  8.75000000e-01   1.51600000e+03] accuracy test:  0.875
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  8.75000000e-01   1.03300000e+03] accuracy test:  0.863636363636
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  8.52272727e-01   9.04000000e+02] accuracy test:  0.863636363636
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  8.75000000e-01   9.10000000e+02] accuracy test:  0.886363636364
# time:  3177.2073539999983

# %% [markdown]
# #### throat surgery

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 1:
        i += 1
        continue
    if i == 2:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_2", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  7.94871795e-01   9.05000000e+02] accuracy test:  0.813559322034
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  8.20512821e-01   1.42100000e+03] accuracy test:  0.813559322034
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.86324786e-01   1.16700000e+03] accuracy test:  0.85593220339
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  6.58119658e-01   9.28000000e+02] accuracy test:  0.762711864407
# alpha:  0.001 max_depth:  2 accuracy validation:  [  8.03418803e-01   9.05000000e+02] accuracy test:  0.813559322034
# alpha:  0.001 max_depth:  3 accuracy validation:  [  8.11965812e-01   1.80300000e+03] accuracy test:  0.813559322034
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.77777778e-01   9.14000000e+02] accuracy test:  0.847457627119
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.52136752e-01   9.49000000e+02] accuracy test:  0.838983050847
# alpha:  1.0 max_depth:  2 accuracy validation:  [  8.03418803e-01   9.01000000e+02] accuracy test:  0.813559322034
# alpha:  1.0 max_depth:  3 accuracy validation:  [  8.20512821e-01   2.16500000e+03] accuracy test:  0.805084745763
# alpha:  1.0 max_depth:  5 accuracy validation:  [  7.69230769e-01   1.47000000e+03] accuracy test:  0.813559322034
# alpha:  1.0 max_depth:  7 accuracy validation:  [  7.77777778e-01   1.10600000e+03] accuracy test:  0.822033898305
# alpha:  10.0 max_depth:  2 accuracy validation:  [  7.94871795e-01   9.01000000e+02] accuracy test:  0.813559322034
# alpha:  10.0 max_depth:  3 accuracy validation:  [  8.20512821e-01   1.01400000e+03] accuracy test:  0.813559322034
# alpha:  10.0 max_depth:  5 accuracy validation:  [  8.29059829e-01   1.15100000e+03] accuracy test:  0.822033898305
# alpha:  10.0 max_depth:  7 accuracy validation:  [  8.20512821e-01   9.10000000e+02] accuracy test:  0.813559322034
# alpha:  100.0 max_depth:  2 accuracy validation:  [  8.29059829e-01   9.01000000e+02] accuracy test:  0.78813559322
# alpha:  100.0 max_depth:  3 accuracy validation:  [  8.03418803e-01   9.69000000e+02] accuracy test:  0.796610169492
# alpha:  100.0 max_depth:  5 accuracy validation:  [  8.03418803e-01   9.08000000e+02] accuracy test:  0.822033898305
# alpha:  100.0 max_depth:  7 accuracy validation:  [  8.11965812e-01   9.25000000e+02] accuracy test:  0.805084745763
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  8.11965812e-01   9.01000000e+02] accuracy test:  0.805084745763
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  8.03418803e-01   9.01000000e+02] accuracy test:  0.78813559322
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  8.29059829e-01   9.80000000e+02] accuracy test:  0.779661016949
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  8.11965812e-01   9.08000000e+02] accuracy test:  0.796610169492
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  7.77777778e-01   9.01000000e+02] accuracy test:  0.771186440678
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  8.11965812e-01   9.01000000e+02] accuracy test:  0.779661016949
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  8.37606838e-01   9.03000000e+02] accuracy test:  0.779661016949
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  8.29059829e-01   9.45000000e+02] accuracy test:  0.805084745763
# time:  4774.5680360000115

# %% [markdown]
# #### wisconsin breast cancer

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 2:
        i += 1
        continue
    if i == 3:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_3", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [   0.95070423  901.        ] accuracy test:  0.951048951049
# alpha:  1e-07 max_depth:  3 accuracy validation:  [   0.94366197  901.        ] accuracy test:  0.951048951049
# alpha:  1e-07 max_depth:  5 accuracy validation:  [   0.90140845  901.        ] accuracy test:  0.93006993007
# alpha:  1e-07 max_depth:  7 accuracy validation:  [   0.90140845  901.        ] accuracy test:  0.93006993007
# alpha:  0.001 max_depth:  2 accuracy validation:  [   0.94366197  901.        ] accuracy test:  0.951048951049
# alpha:  0.001 max_depth:  3 accuracy validation:  [   0.94366197  901.        ] accuracy test:  0.951048951049
# alpha:  0.001 max_depth:  5 accuracy validation:  [   0.91549296  901.        ] accuracy test:  0.93006993007
# alpha:  0.001 max_depth:  7 accuracy validation:  [   0.91549296  901.        ] accuracy test:  0.93006993007
# alpha:  1.0 max_depth:  2 accuracy validation:  [   0.95774648  902.        ] accuracy test:  0.958041958042
# alpha:  1.0 max_depth:  3 accuracy validation:  [   0.93661972  902.        ] accuracy test:  0.965034965035
# alpha:  1.0 max_depth:  5 accuracy validation:  [   0.92253521  902.        ] accuracy test:  0.937062937063
# alpha:  1.0 max_depth:  7 accuracy validation:  [   0.93661972  901.        ] accuracy test:  0.958041958042
# alpha:  10.0 max_depth:  2 accuracy validation:  [   0.94366197  921.        ] accuracy test:  0.965034965035
# alpha:  10.0 max_depth:  3 accuracy validation:  [   0.97183099  907.        ] accuracy test:  0.972027972028
# alpha:  10.0 max_depth:  5 accuracy validation:  [   0.93661972  924.        ] accuracy test:  0.937062937063
# alpha:  10.0 max_depth:  7 accuracy validation:  [   0.94366197  903.        ] accuracy test:  0.93006993007
# alpha:  100.0 max_depth:  2 accuracy validation:  [   0.95070423  908.        ] accuracy test:  0.965034965035
# alpha:  100.0 max_depth:  3 accuracy validation:  [   0.96478873  921.        ] accuracy test:  0.972027972028
# alpha:  100.0 max_depth:  5 accuracy validation:  [   0.96478873  940.        ] accuracy test:  0.937062937063
# alpha:  100.0 max_depth:  7 accuracy validation:  [   0.95774648  908.        ] accuracy test:  0.93006993007
# alpha:  1000.0 max_depth:  2 accuracy validation:  [   0.96478873  912.        ] accuracy test:  0.958041958042
# alpha:  1000.0 max_depth:  3 accuracy validation:  [   0.96478873  946.        ] accuracy test:  0.965034965035
# alpha:  1000.0 max_depth:  5 accuracy validation:  [   0.94366197  902.        ] accuracy test:  0.93006993007
# alpha:  1000.0 max_depth:  7 accuracy validation:  [   0.93661972  901.        ] accuracy test:  0.937062937063
# alpha:  100000.0 max_depth:  2 accuracy validation:  [   0.96478873  942.        ] accuracy test:  0.965034965035
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  9.71830986e-01   1.05900000e+03] accuracy test:  0.923076923077
# alpha:  100000.0 max_depth:  5 accuracy validation:  [   0.97887324  913.        ] accuracy test:  0.944055944056
# alpha:  100000.0 max_depth:  7 accuracy validation:  [   0.97887324  907.        ] accuracy test:  0.937062937063
# time:  4009.529282000003

# %% [markdown]
# #### Indian liver

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 3:
        i += 1
        continue
    if i == 4:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_4", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  7.17241379e-01   2.25200000e+03] accuracy test:  0.68275862069
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  6.89655172e-01   9.03000000e+02] accuracy test:  0.689655172414
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  6.82758621e-01   9.93000000e+02] accuracy test:  0.662068965517
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  6.82758621e-01   1.02100000e+03] accuracy test:  0.634482758621
# alpha:  0.001 max_depth:  2 accuracy validation:  [  6.96551724e-01   1.02700000e+03] accuracy test:  0.68275862069
# alpha:  0.001 max_depth:  3 accuracy validation:  [  7.10344828e-01   1.13500000e+03] accuracy test:  0.68275862069
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.37931034e-01   9.92000000e+02] accuracy test:  0.68275862069
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.31034483e-01   9.31000000e+02] accuracy test:  0.655172413793
# alpha:  1.0 max_depth:  2 accuracy validation:  [  6.82758621e-01   1.20100000e+03] accuracy test:  0.68275862069
# alpha:  1.0 max_depth:  3 accuracy validation:  [  6.82758621e-01   1.15500000e+03] accuracy test:  0.737931034483
# alpha:  1.0 max_depth:  5 accuracy validation:  [  6.82758621e-01   9.22000000e+02] accuracy test:  0.689655172414
# alpha:  1.0 max_depth:  7 accuracy validation:  [  6.96551724e-01   1.04500000e+03] accuracy test:  0.675862068966
# alpha:  10.0 max_depth:  2 accuracy validation:  [  6.75862069e-01   9.19000000e+02] accuracy test:  0.710344827586
# alpha:  10.0 max_depth:  3 accuracy validation:  [  7.10344828e-01   1.56500000e+03] accuracy test:  0.703448275862
# alpha:  10.0 max_depth:  5 accuracy validation:  [  7.03448276e-01   1.09400000e+03] accuracy test:  0.696551724138
# alpha:  10.0 max_depth:  7 accuracy validation:  [  6.89655172e-01   9.03000000e+02] accuracy test:  0.724137931034
# alpha:  100.0 max_depth:  2 accuracy validation:  [  6.82758621e-01   9.97000000e+02] accuracy test:  0.68275862069
# alpha:  100.0 max_depth:  3 accuracy validation:  [  6.75862069e-01   9.19000000e+02] accuracy test:  0.710344827586
# alpha:  100.0 max_depth:  5 accuracy validation:  [  6.89655172e-01   1.24600000e+03] accuracy test:  0.703448275862
# alpha:  100.0 max_depth:  7 accuracy validation:  [  6.75862069e-01   9.90000000e+02] accuracy test:  0.675862068966
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  6.82758621e-01   1.32700000e+03] accuracy test:  0.662068965517
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  7.10344828e-01   9.68000000e+02] accuracy test:  0.696551724138
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  7.10344828e-01   1.46100000e+03] accuracy test:  0.710344827586
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  7.10344828e-01   1.24100000e+03] accuracy test:  0.710344827586
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  6.82758621e-01   2.17400000e+03] accuracy test:  0.648275862069
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  7.10344828e-01   1.06600000e+03] accuracy test:  0.696551724138
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  7.03448276e-01   9.36000000e+02] accuracy test:  0.71724137931
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  6.75862069e-01   9.06000000e+02] accuracy test:  0.68275862069
# time:  2590.78233799999

# %% [markdown]
# #### credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 4:
        i += 1
        continue
    if i == 5:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_5", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  8.28220859e-01   9.71000000e+02] accuracy test:  0.859756097561
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  8.15950920e-01   9.03000000e+02] accuracy test:  0.890243902439
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.36196319e-01   9.10000000e+02] accuracy test:  0.719512195122
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  7.91411043e-01   9.05000000e+02] accuracy test:  0.743902439024
# alpha:  0.001 max_depth:  2 accuracy validation:  [  8.15950920e-01   9.73000000e+02] accuracy test:  0.865853658537
# alpha:  0.001 max_depth:  3 accuracy validation:  [  8.28220859e-01   9.03000000e+02] accuracy test:  0.859756097561
# alpha:  0.001 max_depth:  5 accuracy validation:  [  8.34355828e-01   1.00800000e+03] accuracy test:  0.80487804878
# alpha:  0.001 max_depth:  7 accuracy validation:  [  8.09815951e-01   9.09000000e+02] accuracy test:  0.719512195122
# alpha:  1.0 max_depth:  2 accuracy validation:  [  8.40490798e-01   9.56000000e+02] accuracy test:  0.884146341463
# alpha:  1.0 max_depth:  3 accuracy validation:  [  8.28220859e-01   9.59000000e+02] accuracy test:  0.871951219512
# alpha:  1.0 max_depth:  5 accuracy validation:  [  8.46625767e-01   1.03800000e+03] accuracy test:  0.792682926829
# alpha:  1.0 max_depth:  7 accuracy validation:  [  7.60736196e-01   9.06000000e+02] accuracy test:  0.719512195122
# alpha:  10.0 max_depth:  2 accuracy validation:  [  8.46625767e-01   9.04000000e+02] accuracy test:  0.878048780488
# alpha:  10.0 max_depth:  3 accuracy validation:  [  8.28220859e-01   9.10000000e+02] accuracy test:  0.878048780488
# alpha:  10.0 max_depth:  5 accuracy validation:  [  8.52760736e-01   1.11400000e+03] accuracy test:  0.829268292683
# alpha:  10.0 max_depth:  7 accuracy validation:  [  8.03680982e-01   1.01700000e+03] accuracy test:  0.774390243902
# alpha:  100.0 max_depth:  2 accuracy validation:  [  8.46625767e-01   1.85500000e+03] accuracy test:  0.871951219512
# alpha:  100.0 max_depth:  3 accuracy validation:  [  8.28220859e-01   9.13000000e+02] accuracy test:  0.878048780488
# alpha:  100.0 max_depth:  5 accuracy validation:  [  8.15950920e-01   9.04000000e+02] accuracy test:  0.865853658537
# alpha:  100.0 max_depth:  7 accuracy validation:  [  8.34355828e-01   9.06000000e+02] accuracy test:  0.810975609756
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  8.46625767e-01   1.14600000e+03] accuracy test:  0.878048780488
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  8.46625767e-01   1.53900000e+03] accuracy test:  0.884146341463
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  8.09815951e-01   9.01000000e+02] accuracy test:  0.859756097561
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  7.85276074e-01   9.26000000e+02] accuracy test:  0.823170731707
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  8.40490798e-01   1.46300000e+03] accuracy test:  0.865853658537
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  8.15950920e-01   1.24700000e+03] accuracy test:  0.84756097561
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  7.97546012e-01   1.10200000e+03] accuracy test:  0.841463414634
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  7.85276074e-01   1.00900000e+03] accuracy test:  0.80487804878
# time:  6293.410185000001

# %% [markdown]
# #### Australian credit approval

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 5:
        i += 1
        continue
    if i == 6:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_6", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  8.31395349e-01   9.03000000e+02] accuracy test:  0.832369942197
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  8.25581395e-01   9.01000000e+02] accuracy test:  0.820809248555
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.96511628e-01   9.19000000e+02] accuracy test:  0.809248554913
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  7.55813953e-01   9.03000000e+02] accuracy test:  0.791907514451
# alpha:  0.001 max_depth:  2 accuracy validation:  [  8.31395349e-01   9.03000000e+02] accuracy test:  0.809248554913
# alpha:  0.001 max_depth:  3 accuracy validation:  [  8.19767442e-01   9.01000000e+02] accuracy test:  0.809248554913
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.90697674e-01   9.49000000e+02] accuracy test:  0.820809248555
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.38372093e-01   9.03000000e+02] accuracy test:  0.809248554913
# alpha:  1.0 max_depth:  2 accuracy validation:  [  8.31395349e-01   9.01000000e+02] accuracy test:  0.820809248555
# alpha:  1.0 max_depth:  3 accuracy validation:  [  8.25581395e-01   9.25000000e+02] accuracy test:  0.843930635838
# alpha:  1.0 max_depth:  5 accuracy validation:  [  8.19767442e-01   9.02000000e+02] accuracy test:  0.843930635838
# alpha:  1.0 max_depth:  7 accuracy validation:  [  8.08139535e-01   9.18000000e+02] accuracy test:  0.838150289017
# alpha:  10.0 max_depth:  2 accuracy validation:  [  8.08139535e-01   9.06000000e+02] accuracy test:  0.838150289017
# alpha:  10.0 max_depth:  3 accuracy validation:  [  8.48837209e-01   9.01000000e+02] accuracy test:  0.843930635838
# alpha:  10.0 max_depth:  5 accuracy validation:  [  8.60465116e-01   1.00400000e+03] accuracy test:  0.826589595376
# alpha:  10.0 max_depth:  7 accuracy validation:  [  8.54651163e-01   9.91000000e+02] accuracy test:  0.838150289017
# alpha:  100.0 max_depth:  2 accuracy validation:  [  8.31395349e-01   9.27000000e+02] accuracy test:  0.85549132948
# alpha:  100.0 max_depth:  3 accuracy validation:  [  8.60465116e-01   9.59000000e+02] accuracy test:  0.832369942197
# alpha:  100.0 max_depth:  5 accuracy validation:  [  8.48837209e-01   9.08000000e+02] accuracy test:  0.809248554913
# alpha:  100.0 max_depth:  7 accuracy validation:  [  8.54651163e-01   1.05000000e+03] accuracy test:  0.820809248555
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  8.48837209e-01   9.23000000e+02] accuracy test:  0.843930635838
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  8.72093023e-01   1.16800000e+03] accuracy test:  0.815028901734
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  8.72093023e-01   1.12600000e+03] accuracy test:  0.791907514451
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  8.19767442e-01   9.10000000e+02] accuracy test:  0.791907514451
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  8.54651163e-01   9.34000000e+02] accuracy test:  0.809248554913
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  8.66279070e-01   9.01000000e+02] accuracy test:  0.815028901734
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  8.37209302e-01   9.12000000e+02] accuracy test:  0.815028901734
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  8.13953488e-01   1.01700000e+03] accuracy test:  0.78612716763
# time:  7381.170213999983

# %% [markdown]
# #### blood transfusion

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 6:
        i += 1
        continue
    if i == 7:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_7", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  7.86096257e-01   9.01000000e+02] accuracy test:  0.754010695187
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  8.07486631e-01   1.03800000e+03] accuracy test:  0.737967914439
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.80748663e-01   9.21000000e+02] accuracy test:  0.716577540107
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  7.43315508e-01   9.31000000e+02] accuracy test:  0.732620320856
# alpha:  0.001 max_depth:  2 accuracy validation:  [  7.86096257e-01   9.01000000e+02] accuracy test:  0.754010695187
# alpha:  0.001 max_depth:  3 accuracy validation:  [  8.02139037e-01   1.10500000e+03] accuracy test:  0.754010695187
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.80748663e-01   9.42000000e+02] accuracy test:  0.732620320856
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.48663102e-01   9.15000000e+02] accuracy test:  0.711229946524
# alpha:  1.0 max_depth:  2 accuracy validation:  [  7.86096257e-01   9.01000000e+02] accuracy test:  0.748663101604
# alpha:  1.0 max_depth:  3 accuracy validation:  [  8.02139037e-01   9.12000000e+02] accuracy test:  0.743315508021
# alpha:  1.0 max_depth:  5 accuracy validation:  [  7.64705882e-01   9.03000000e+02] accuracy test:  0.705882352941
# alpha:  1.0 max_depth:  7 accuracy validation:  [  7.70053476e-01   9.09000000e+02] accuracy test:  0.705882352941
# alpha:  10.0 max_depth:  2 accuracy validation:  [  7.91443850e-01   9.38000000e+02] accuracy test:  0.737967914439
# alpha:  10.0 max_depth:  3 accuracy validation:  [  8.12834225e-01   9.02000000e+02] accuracy test:  0.743315508021
# alpha:  10.0 max_depth:  5 accuracy validation:  [  7.80748663e-01   9.60000000e+02] accuracy test:  0.743315508021
# alpha:  10.0 max_depth:  7 accuracy validation:  [  7.70053476e-01   9.04000000e+02] accuracy test:  0.711229946524
# alpha:  100.0 max_depth:  2 accuracy validation:  [  8.23529412e-01   9.05000000e+02] accuracy test:  0.743315508021
# alpha:  100.0 max_depth:  3 accuracy validation:  [  8.07486631e-01   9.08000000e+02] accuracy test:  0.791443850267
# alpha:  100.0 max_depth:  5 accuracy validation:  [  7.64705882e-01   9.37000000e+02] accuracy test:  0.727272727273
# alpha:  100.0 max_depth:  7 accuracy validation:  [  7.59358289e-01   9.24000000e+02] accuracy test:  0.72192513369
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  8.18181818e-01   2.07400000e+03] accuracy test:  0.775401069519
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  8.02139037e-01   9.31000000e+02] accuracy test:  0.770053475936
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  7.91443850e-01   9.44000000e+02] accuracy test:  0.737967914439
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  7.54010695e-01   9.14000000e+02] accuracy test:  0.705882352941
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  8.18181818e-01   1.09400000e+03] accuracy test:  0.780748663102
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  8.12834225e-01   1.60000000e+03] accuracy test:  0.791443850267
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  7.96791444e-01   9.45000000e+02] accuracy test:  0.72192513369
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  7.80748663e-01   9.07000000e+02] accuracy test:  0.72192513369
# time:  2770.35366600001

# %% [markdown]
# #### Pima Indians diabetes

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 7:
        i += 1
        continue
    if i == 8:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_8", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  7.13541667e-01   1.00500000e+03] accuracy test:  0.796875
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  7.39583333e-01   1.41300000e+03] accuracy test:  0.78125
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.39583333e-01   1.02900000e+03] accuracy test:  0.786458333333
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  7.34375000e-01   1.01200000e+03] accuracy test:  0.765625
# alpha:  0.001 max_depth:  2 accuracy validation:  [  7.13541667e-01   1.00500000e+03] accuracy test:  0.796875
# alpha:  0.001 max_depth:  3 accuracy validation:  [  7.23958333e-01   1.41300000e+03] accuracy test:  0.776041666667
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.55208333e-01   1.01500000e+03] accuracy test:  0.786458333333
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.23958333e-01   1.00300000e+03] accuracy test:  0.786458333333
# alpha:  1.0 max_depth:  2 accuracy validation:  [  7.13541667e-01   9.07000000e+02] accuracy test:  0.776041666667
# alpha:  1.0 max_depth:  3 accuracy validation:  [  7.23958333e-01   1.61100000e+03] accuracy test:  0.78125
# alpha:  1.0 max_depth:  5 accuracy validation:  [  7.44791667e-01   1.09900000e+03] accuracy test:  0.78125
# alpha:  1.0 max_depth:  7 accuracy validation:  [  7.34375000e-01   9.29000000e+02] accuracy test:  0.791666666667
# alpha:  10.0 max_depth:  2 accuracy validation:  [  7.34375000e-01   1.08200000e+03] accuracy test:  0.8125
# alpha:  10.0 max_depth:  3 accuracy validation:  [  7.34375000e-01   1.54400000e+03] accuracy test:  0.776041666667
# alpha:  10.0 max_depth:  5 accuracy validation:  [  7.50000000e-01   1.21200000e+03] accuracy test:  0.765625
# alpha:  10.0 max_depth:  7 accuracy validation:  [  7.60416667e-01   9.66000000e+02] accuracy test:  0.765625
# alpha:  100.0 max_depth:  2 accuracy validation:  [  7.29166667e-01   9.20000000e+02] accuracy test:  0.78125
# alpha:  100.0 max_depth:  3 accuracy validation:  [  7.29166667e-01   9.92000000e+02] accuracy test:  0.765625
# alpha:  100.0 max_depth:  5 accuracy validation:  [  7.55208333e-01   9.15000000e+02] accuracy test:  0.760416666667
# alpha:  100.0 max_depth:  7 accuracy validation:  [  7.39583333e-01   1.00600000e+03] accuracy test:  0.78125
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  6.92708333e-01   9.17000000e+02] accuracy test:  0.791666666667
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  7.13541667e-01   9.55000000e+02] accuracy test:  0.760416666667
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  7.23958333e-01   9.54000000e+02] accuracy test:  0.760416666667
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  7.18750000e-01   9.21000000e+02] accuracy test:  0.765625
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  7.03125000e-01   9.41000000e+02] accuracy test:  0.802083333333
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  7.18750000e-01   9.21000000e+02] accuracy test:  0.776041666667
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  7.13541667e-01   9.25000000e+02] accuracy test:  0.755208333333
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  7.03125000e-01   9.54000000e+02] accuracy test:  0.739583333333
# time:  3142.264301999996

# %% [markdown]
# #### mammographic mass

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 8:
        i += 1
        continue
    if i == 9:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_9", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [  7.98076923e-01   1.20000000e+03] accuracy test:  0.802884615385
# alpha:  1e-07 max_depth:  3 accuracy validation:  [  7.69230769e-01   9.02000000e+02] accuracy test:  0.778846153846
# alpha:  1e-07 max_depth:  5 accuracy validation:  [  7.54807692e-01   9.03000000e+02] accuracy test:  0.759615384615
# alpha:  1e-07 max_depth:  7 accuracy validation:  [  7.50000000e-01   9.23000000e+02] accuracy test:  0.778846153846
# alpha:  0.001 max_depth:  2 accuracy validation:  [  7.93269231e-01   1.21000000e+03] accuracy test:  0.798076923077
# alpha:  0.001 max_depth:  3 accuracy validation:  [  7.88461538e-01   9.41000000e+02] accuracy test:  0.783653846154
# alpha:  0.001 max_depth:  5 accuracy validation:  [  7.54807692e-01   9.03000000e+02] accuracy test:  0.759615384615
# alpha:  0.001 max_depth:  7 accuracy validation:  [  7.59615385e-01   9.15000000e+02] accuracy test:  0.778846153846
# alpha:  1.0 max_depth:  2 accuracy validation:  [  8.02884615e-01   9.04000000e+02] accuracy test:  0.798076923077
# alpha:  1.0 max_depth:  3 accuracy validation:  [  7.78846154e-01   1.30000000e+03] accuracy test:  0.778846153846
# alpha:  1.0 max_depth:  5 accuracy validation:  [  7.59615385e-01   9.21000000e+02] accuracy test:  0.759615384615
# alpha:  1.0 max_depth:  7 accuracy validation:  [  7.50000000e-01   9.14000000e+02] accuracy test:  0.774038461538
# alpha:  10.0 max_depth:  2 accuracy validation:  [  8.02884615e-01   9.97000000e+02] accuracy test:  0.798076923077
# alpha:  10.0 max_depth:  3 accuracy validation:  [  7.69230769e-01   9.31000000e+02] accuracy test:  0.769230769231
# alpha:  10.0 max_depth:  5 accuracy validation:  [  7.45192308e-01   9.14000000e+02] accuracy test:  0.764423076923
# alpha:  10.0 max_depth:  7 accuracy validation:  [  7.40384615e-01   9.13000000e+02] accuracy test:  0.774038461538
# alpha:  100.0 max_depth:  2 accuracy validation:  [  7.93269231e-01   9.48000000e+02] accuracy test:  0.8125
# alpha:  100.0 max_depth:  3 accuracy validation:  [  7.78846154e-01   9.55000000e+02] accuracy test:  0.778846153846
# alpha:  100.0 max_depth:  5 accuracy validation:  [  7.59615385e-01   9.13000000e+02] accuracy test:  0.764423076923
# alpha:  100.0 max_depth:  7 accuracy validation:  [  7.40384615e-01   9.05000000e+02] accuracy test:  0.769230769231
# alpha:  1000.0 max_depth:  2 accuracy validation:  [  7.98076923e-01   9.85000000e+02] accuracy test:  0.8125
# alpha:  1000.0 max_depth:  3 accuracy validation:  [  7.88461538e-01   9.03000000e+02] accuracy test:  0.783653846154
# alpha:  1000.0 max_depth:  5 accuracy validation:  [  7.59615385e-01   1.07200000e+03] accuracy test:  0.764423076923
# alpha:  1000.0 max_depth:  7 accuracy validation:  [  7.40384615e-01   9.38000000e+02] accuracy test:  0.769230769231
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  8.02884615e-01   9.18000000e+02] accuracy test:  0.807692307692
# alpha:  100000.0 max_depth:  3 accuracy validation:  [  7.59615385e-01   9.10000000e+02] accuracy test:  0.778846153846
# alpha:  100000.0 max_depth:  5 accuracy validation:  [  7.45192308e-01   9.05000000e+02] accuracy test:  0.774038461538
# alpha:  100000.0 max_depth:  7 accuracy validation:  [  7.54807692e-01   9.05000000e+02] accuracy test:  0.769230769231
# time:  5927.9008160000085

# %% [markdown]
# #### banknote authentication

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i != 9:
        i += 1
        continue
    if i == 10:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 3000
    
    max_depths = [2, 3, 5, 7]
    alpha_lst = [1e-7, 1e-3, 1.0, 10.0, 100.0, 1000.0, 1e+5]
    
    best_scores = np.zeros((len(alpha_lst), len(max_depths), 2))
    val_scores = np.zeros((n_estimators, len(alpha_lst), len(max_depths)))
    final_scores = np.zeros((len(alpha_lst), len(max_depths)))
    for j, alpha in enumerate(alpha_lst):
        for k, max_depth in enumerate(max_depths):
            clf = GradBoost(Ridge_CART(MSE(), MeanSegmentor(), alpha=alpha, max_depth=max_depth, method='hard'), 
                            n_estimators, loss='exp', shrinkage=0.1)
            clf.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=900, cross_val=True)
            val_scores[:, j, k] = 1 - np.asarray(clf.loss_val)
            best_scores[j, k, 0] = val_scores[clf.base_learners_count - 1, j, k]
            best_scores[j, k, 1] = clf.base_learners_count
            y_pred = clf.predict(X_test)
            final_scores[j, k] = accuracy(y_pred, y_test)
            print("alpha: ", alpha,
                  "max_depth: ", max_depth,
                  "accuracy validation: ", best_scores[j, k, :],
                  "accuracy test: ", final_scores[j, k])
    i += 1
    
    print("time: ", clock() - start)

np.save("HARD_Ridge_CART_10", (val_scores, best_scores, final_scores))
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# alpha:  1e-07 max_depth:  2 accuracy validation:  [   0.98833819  910.        ] accuracy test:  0.98833819242
# alpha:  1e-07 max_depth:  3 accuracy validation:  [   0.98542274  914.        ] accuracy test:  0.97667638484
# alpha:  1e-07 max_depth:  5 accuracy validation:  [   1.  907.] accuracy test:  1.0
# alpha:  1e-07 max_depth:  7 accuracy validation:  [   1.  901.] accuracy test:  0.997084548105
# alpha:  0.001 max_depth:  2 accuracy validation:  [   0.98833819  910.        ] accuracy test:  0.98833819242
# alpha:  0.001 max_depth:  3 accuracy validation:  [   0.98542274  914.        ] accuracy test:  0.97667638484
# alpha:  0.001 max_depth:  5 accuracy validation:  [   1.  907.] accuracy test:  0.997084548105
# alpha:  0.001 max_depth:  7 accuracy validation:  [   1.  901.] accuracy test:  0.997084548105
# alpha:  1.0 max_depth:  2 accuracy validation:  [   0.98833819  912.        ] accuracy test:  0.98833819242
# alpha:  1.0 max_depth:  3 accuracy validation:  [   0.99125364  970.        ] accuracy test:  0.985422740525
# alpha:  1.0 max_depth:  5 accuracy validation:  [   1.  906.] accuracy test:  1.0
# alpha:  1.0 max_depth:  7 accuracy validation:  [   0.99708455  901.        ] accuracy test:  0.99416909621
# alpha:  10.0 max_depth:  2 accuracy validation:  [   0.98833819  913.        ] accuracy test:  0.985422740525
# alpha:  10.0 max_depth:  3 accuracy validation:  [  1.00000000e+00   1.02300000e+03] accuracy test:  1.0
# alpha:  10.0 max_depth:  5 accuracy validation:  [   0.9941691  904.       ] accuracy test:  0.991253644315
# alpha:  10.0 max_depth:  7 accuracy validation:  [   1.  901.] accuracy test:  0.997084548105
# alpha:  100.0 max_depth:  2 accuracy validation:  [   1.  992.] accuracy test:  0.99416909621
# alpha:  100.0 max_depth:  3 accuracy validation:  [   1.  914.] accuracy test:  1.0
# alpha:  100.0 max_depth:  5 accuracy validation:  [   1.  911.] accuracy test:  1.0
# alpha:  100.0 max_depth:  7 accuracy validation:  [   0.99708455  907.        ] accuracy test:  0.99416909621
# alpha:  1000.0 max_depth:  2 accuracy validation:  [   1.  984.] accuracy test:  1.0
# alpha:  1000.0 max_depth:  3 accuracy validation:  [   1.  958.] accuracy test:  1.0
# alpha:  1000.0 max_depth:  5 accuracy validation:  [   0.99708455  902.        ] accuracy test:  1.0
# alpha:  1000.0 max_depth:  7 accuracy validation:  [   1.  905.] accuracy test:  1.0
# alpha:  100000.0 max_depth:  2 accuracy validation:  [  1.00000000e+00   1.01900000e+03] accuracy test:  1.0
# alpha:  100000.0 max_depth:  3 accuracy validation:  [   0.99708455  919.        ] accuracy test:  1.0
# alpha:  100000.0 max_depth:  5 accuracy validation:  [   0.99708455  919.        ] accuracy test:  1.0
# alpha:  100000.0 max_depth:  7 accuracy validation:  [   0.9941691  902.       ] accuracy test:  1.0
# time:  2838.2942040000053

# %% [markdown]
# В следующей таблице сравниваются accuracy алгоритмов.

# %% [markdown]
# |*Датасеты*|**Gradient Boosting**|**Random CART**|**Random CART(c)**|**Ridge CART**|**Hard Ridge CART**|
# |------------------------------------------------------------------------------------------------------|
# |ionosphere|0.864|**0.909**|**0.909**|**0.886**|**0.886**|
# |throat surgery|0.805|**0.822**|**0.81**|**0.805**|0.78|
# |wisconsin breast cancer|0.916|**0.951**|**0.965**|**0.958**|**0.944**|
# |Indian liver|0.669|**0.683**|**0.731**|0.662|**0.683**|
# |credit approval|0.81|**0.866**|**0.866**|**0.848**|**0.829**|
# |Australian credit approval|0.82|**0.832**|**0.8613**|**0.8497**|0.815|
# |blood transfusion|0.74|**0.77**|**0.78**|**0.77**|0.743|
# |Pima Indians diabetes|0.792|0.792|**0.807**|0.766|0.766|
# |mammographic mass|0.788|**0.8125**|**0.8077**|**0.8077**|**0.8077**|
# |banknote authentication|0.991|**1.0**|**1.0**|**1.0**|**1.0**|

# %%
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

def plot_surface(X, y, clf):
    h = 0.05
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    Z = Z.reshape(xx.shape)
    plt.figure(figsize=(8, 8))
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=500, n_features=2,
                           n_informative=2, n_redundant=0, n_repeated=0,
                           n_classes=2, n_clusters_per_class=2,
                           flip_y=0.05, class_sep=0.8, random_state=12)

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter')
plt.show()

# %%
clf = GradBoost(HouseHolderCART(MSE(), MeanSegmentor(), max_depth=2), 
                        10, loss='exp', shrinkage=0.1)
clf.fit(X, y)

plot_surface(X, y, clf)

# %%
clf = GradBoost(BUTIF(max_leaf=3, 
                      linear_model=LogisticRegression(n_jobs=-1), 
                      task='regression'), 
                100, loss='exp', shrinkage=0.1)
clf.fit(X, y)

plot_surface(X, y, clf)

# %%
clf = GradBoost(Rand_CART(MSE(), MeanSegmentor(), max_depth=9), 
                10, loss='exp', shrinkage=0.1)
clf.fit(X, y)

plot_surface(X, y, clf)

# %%
clf = GradBoost(DecisionTreeRegressor(max_leaf_nodes=5),
                10, loss='exp', shrinkage=0.1)
clf.fit(X, y)

plot_surface(X, y, clf)

# %%
clf = XGBClassifier(n_estimators=200)
clf.fit(X, y)

plot_surface(X, y, clf)

# %%
from copy import deepcopy
import numpy as np
from segmentor import MeanSegmentor, MSE

#add usual split procedure for initialize

class ContinuouslyOptimizedObliqueRegressionTree():
    
    def __init__(self, impurity, segmentor, nu=1.0, thau=10, max_iter=100, tol=1e-6, step=0.1):
        self.impurity = impurity
        self.segmentor = segmentor
        self.nu = nu
        self.thau = thau
        self.max_iter = max_iter
        self.tol = tol
        self.step = step
    
    def fit(self, X, y):
        
        X_train = deepcopy(X)
        
        impurity, sr, left_indices, right_indices = self.segmentor(X_train, y, self.impurity)
        
        X_train = np.hstack((X_train, np.ones(X_train.shape[0])[:, np.newaxis]))
        n_objects, n_features = X_train.shape
        
        w_new = np.zeros(n_features)
        w_new[sr[0]] = 1.0
        w_new[-1] = -sr[1]
        theta_left = y[left_indices].mean()
        theta_right = y[right_indices].mean()
        self.l = []
        l_old = np.inf
        l_new = self.objective(w_new, theta_left, theta_right, X_train, y)
        it = 0
        
        while np.abs(l_old - l_new) > self.tol:
            it += 1
            w_old = w_new
            for i in range(self.thau):
                ind_batch = np.random.choice(np.arange(n_objects), size=1)
                X_batch = X_train[ind_batch, :]
                y_batch = y[ind_batch]
                
                s = np.sign((w_old * X_batch).sum())
                
                if -(w_new * X_batch).sum() + (theta_left - y_batch) ** 2 >=\
                    (w_new * X_batch).sum() + (theta_right - y_batch) ** 2:
                    w_new = w_new + self.step * (1 + s) * X_batch
                    theta_left = theta_left - 2 * self.step * (theta_left - y_batch)
                else:
                    w_new = w_new - self.step * (1 - s) * X_batch 
                    theta_right = theta_right - 2 * self.step * (theta_right - y_batch)
                
                if (w_new * w_new).sum() > self.nu:
                    w_new = np.sqrt(self.thau) * w_new / np.linalg.norm(w_new)
            
            l_old = self.objective(w_old, theta_left, theta_right, X_train, y)
            l_new = self.objective(w_new, theta_left, theta_right, X_train, y)
            self.l.append(self.objective(w_new, theta_left, theta_right, X_train, y))
            if it >= self.max_iter:
                break
        
        self.weights = w_new
        self.theta_left = theta_left
        self.theta_right = theta_right
        
    def objective(self, w, theta_left, theta_right, X, y):
        loss = np.vstack((-w.dot(X.T) + (theta_left - y) ** 2,
                   w.dot(X.T) + (theta_right - y) ** 2))
        return (np.max(loss, axis=0) - np.abs(w.dot(X.T))).sum()
    
    def predict(self, X):
        
        X_test = deepcopy(X)
        X_test = np.hstack((X_test, np.ones(X_test.shape[0])[:, np.newaxis]))
        n_objects, n_features = X_test.shape
        y = np.zeros(n_objects)
        mask = (self.weights.dot(X_test.T) >= 0)[0]
        y[mask] = self.theta_right
        y[np.logical_not(mask)] = self.theta_left
        
        return y

# %%
from sklearn.base import BaseEstimator
import numpy as np
from numpy.linalg import eig, solve

class Node:

    def __init__(self, depth, labels, **kwargs):
        self.depth = depth
        self.labels = labels
        self.is_leaf = kwargs.get('is_leaf', False)
        self._split_rules = kwargs.get('split_rules', None)
        self._rotation_matrix = kwargs.get('rotation_matrix', None)
        self._mu = kwargs.get('mu', None)
        self._left_child = kwargs.get('left_child', None)
        self._right_child = kwargs.get('right_child', None)

        if not self.is_leaf:
            assert self._split_rules
            assert self._left_child
            assert self._right_child

    def get_child(self, datum):
        if self.is_leaf:
            raise StandardError("Leaf node does not have children.")
        i, treshold = self._split_rules
        X_hat = solve(self._rotation_matrix, datum - self._mu)
        
        if X_hat[i] < treshold:
            return self.left_child
        else:
            return self.right_child

    @property
    def label(self):
        if not hasattr(self, '_label'):
            self._label = np.mean(self.labels)
        return self._label

    @property
    def split_rules(self):
        if self.is_leaf:
            raise StandardError("Leaf node does not have split rule.")
        return self._split_rules

    @property
    def left_child(self):
        if self.is_leaf:
            raise StandardError("Leaf node does not have split rule.")
        return self._left_child

    @property
    def right_child(self):
        if self.is_leaf:
            raise StandardError("Leaf node does not have split rule.")
        return self._right_child


class Whiten_CART(BaseEstimator):

    def __init__(self, impurity, segmentor, **kwargs):
        self.impurity = impurity
        self.segmentor = segmentor
        self._max_depth = kwargs.get('max_depth', None)
        self._min_samples = kwargs.get('min_samples', 2)
        self._root = None
        self._nodes = []
    
    def _terminate(self, X, y, cur_depth):
            if self._max_depth != None and cur_depth == self._max_depth:
                # maximum depth reached.
                return True
            elif y.size < self._min_samples:
                # minimum number of samples reached.
                return True
            elif np.unique(y).size == 1:
                return True
            else:
                return False
    
    def _generate_leaf_node(self, cur_depth, y):
            node = Node(cur_depth, y, is_leaf=True)
            self._nodes.append(node)
            return node
    
    def _generate_node(self, X, y, cur_depth):
        if self._terminate(X, y, cur_depth):
            return self._generate_leaf_node(cur_depth, y)
        else:
            n_objects, n_features = X.shape
            
            mu = X.mean(axis=0)
            central_X = X - mu
            covariance_matrix = (1 / (n_objects - 1)) * central_X.T.dot(central_X)
            eig_value, eig_vectors = eig(covariance_matrix)
            sqrt_cov_matrix = eig_vectors.dot(np.sqrt(np.diag(eig_value))).dot(eig_vectors.T)
            try:
                X_hat = (solve(sqrt_cov_matrix, central_X.T)).T
            except:
                print(eig_value)
            impurity, sr, left_indices, right_indices = self.segmentor(X_hat, y, self.impurity)
            
            if not sr:
                return self._generate_leaf_node(cur_depth, y)
            
            X_left, y_left = X[left_indices], y[left_indices]
            X_right, y_right = X[right_indices], y[right_indices]

            node = Node(cur_depth, y,
                        split_rules=sr,
                        rotation_matrix=sqrt_cov_matrix,
                        mu=mu,
                        left_child=self._generate_node(X_left, y_left, cur_depth + 1),
                        right_child=self._generate_node(X_right, y_right, cur_depth + 1),
                        is_leaf=False)
            self._nodes.append(node)
            return node
    
    def fit(self, X, y):
        
        self._root = self._generate_node(X, y, 0)

    def predict(self, X):
        def predict_single(datum):
            cur_node = self._root
            while not cur_node.is_leaf:
                cur_node = cur_node.get_child(datum)
            return cur_node.label
        
        if not self._root:
            raise StandardError("Decision tree has not been trained.")
        size = X.shape[0]
        predictions = np.empty((size, ), dtype=float)
        for i in range(size): 
            predictions[i] = predict_single(X[i, :])
        return predictions

    def score(self, data, labels):
        if not self._root:
            raise StandardError("Decision tree has not been trained.")
        predictions = self.predict(data)
        correct_count = np.count_nonzero(predictions == labels)
        return correct_count / labels.shape[0]

# %%
i = 0
for data_key, data in datasets.items():
    start = clock()
    if i == 1:
        break
    X_train = data.X_train
    X_val = data.X_val
    y_train = data.Y_train.astype('int')
    y_val = data.Y_val.astype('int')
    X_test = data.X_test
    y_test = data.Y_test    
    n_estimators = 100
    
    max_depths = [1, 3, 5, 7]
    
    best_scores2 = np.zeros((len(max_depths), 2))
    val_scores2 = np.zeros((n_estimators, len(max_depths)))
    for k, max_depth in enumerate(max_depths):
        clf2 = GradBoost(Whiten_CART(MSE(), MeanSegmentor(), max_depth=max_depth), 
                        n_estimators, loss='exp', shrinkage=0.1)
        clf2.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=20, cross_val=True)
        y_pred = clf2.predict(X_test)
        final_acc = accuracy(y_pred, y_test)
        val_scores2[:, k] = 1 - np.asarray(clf2.loss_val)
        best_scores2[k, 0] = val_scores2[clf2.base_learners_count - 1, k]
        best_scores2[k, 1] = clf2.base_learners_count
        print("max_depth: ", max_depth,
              "accuracy: ", best_scores2[k],
             "accuracy final:", final_acc)
    i += 1
    
    print("time: ", clock() - start)
# Out:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if X_val != None and y_val != None:
# max_depth:  1 accuracy:  [  0.78409091  21.        ] accuracy final: 0.727272727273
# max_depth:  3 accuracy:  [  0.79545455  41.        ] accuracy final: 0.784090909091
# [  3.18455219e+01 +0.00000000e+00j   1.31478367e+01 +0.00000000e+00j
#    1.62607759e-01 +0.00000000e+00j   6.52909204e-02 +0.00000000e+00j
#   -4.23990372e-07 +0.00000000e+00j   4.06021968e-07 +0.00000000e+00j
#    3.74253290e-07 +0.00000000e+00j  -3.27761029e-07 +2.49545473e-09j
#   -3.27761029e-07 -2.49545473e-09j  -2.48607563e-07 +0.00000000e+00j
#    2.70287899e-07 +3.94647692e-08j   2.70287899e-07 -3.94647692e-08j
#    2.66981203e-07 +2.03180868e-08j   2.66981203e-07 -2.03180868e-08j
#   -2.07869988e-07 +0.00000000e+00j  -1.64320909e-07 +0.00000000e+00j
#   -1.51795106e-07 +0.00000000e+00j   1.60362973e-07 +0.00000000e+00j
#    1.39861655e-07 +0.00000000e+00j   1.28332985e-07 +0.00000000e+00j
#   -1.06439124e-07 +0.00000000e+00j   8.32688087e-08 +0.00000000e+00j
#   -6.39944631e-08 +1.81154947e-09j  -6.39944631e-08 -1.81154947e-09j
#   -4.03229876e-08 +0.00000000e+00j   5.47656214e-08 +0.00000000e+00j
#   -2.44481519e-08 +0.00000000e+00j   4.01056930e-08 +0.00000000e+00j
#   -8.67682282e-09 +0.00000000e+00j   4.63092098e-09 +0.00000000e+00j
#    2.43437128e-08 +0.00000000e+00j   2.76271326e-08 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-177-d8b8035d418c> in <module>()
#      19         clf2 = GradBoost(Whiten_CART(MSE(), MeanSegmentor(), max_depth=max_depth),
#      20                         n_estimators, loss='exp', shrinkage=0.1)
# ---> 21         clf2.fit(X_train, y_train, X_val=X_val, y_val=y_val, bad_iters_count=20, cross_val=True)
#      22         y_pred = clf2.predict(X_test)
#      23         final_acc = accuracy(y_pred, y_test)
#
# /home/anuar/Рабочий стол/Student/4 kurs/1 sem/Course work/code/gradboost.py in fit(self, X, y, X_val, y_val, bad_iters_count, cross_val)
#     107
#     108             base_learner = deepcopy(self.base_learner) # recreate base learner
# --> 109             base_learner.fit(X, z)
#     110
#     111             if isinstance(base_learner, skl.tree.tree.DecisionTreeRegressor) and (self.refit_tree == True): # tree refitting
#
# <ipython-input-176-e552a4fa2247> in fit(self, X, y)
#     118     def fit(self, X, y):
#     119
# --> 120         self._root = self._generate_node(X, y, 0)
#     121
#     122     def predict(self, X):
#
# <ipython-input-176-e552a4fa2247> in _generate_node(self, X, y, cur_depth)
#     110                         rotation_matrix=sqrt_cov_matrix,
#     111                         mu=mu,
# --> 112                         left_child=self._generate_node(X_left, y_left, cur_depth + 1),
#     113                         right_child=self._generate_node(X_right, y_right, cur_depth + 1),
#     114                         is_leaf=False)
#
# <ipython-input-176-e552a4fa2247> in _generate_node(self, X, y, cur_depth)
#     111                         mu=mu,
#     112                         left_child=self._generate_node(X_left, y_left, cur_depth + 1),
# --> 113                         right_child=self._generate_node(X_right, y_right, cur_depth + 1),
#     114                         is_leaf=False)
#     115             self._nodes.append(node)
#
# <ipython-input-176-e552a4fa2247> in _generate_node(self, X, y, cur_depth)
#     111                         mu=mu,
#     112                         left_child=self._generate_node(X_left, y_left, cur_depth + 1),
# --> 113                         right_child=self._generate_node(X_right, y_right, cur_depth + 1),
#     114                         is_leaf=False)
#     115             self._nodes.append(node)
#
# <ipython-input-176-e552a4fa2247> in _generate_node(self, X, y, cur_depth)
#      98             except:
#      99                 print(eig_value)
# --> 100             impurity, sr, left_indices, right_indices = self.segmentor(X_hat, y, self.impurity)
#     101
#     102             if not sr:
#
# UnboundLocalError: local variable 'X_hat' referenced before assignment
